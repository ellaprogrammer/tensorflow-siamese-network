# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
im = plt.imread('../Desktop/monkeyface/flower.jpg')

plt.imshow(im)
print(im.shape)

im.setflags(write=1)
im.flags
# Out:
# (405, 720, 3)
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
# def f(x, y):
#     return np.sin(x)

# x = np.linspace(0, im.shape[0], im.shape[0]/100)
# y = np.linspace(0, im.shape[1], im.shape[1]/100)
# # print(x)
# X, Y = np.meshgrid(x, y)
# print(Y.shape)
# Z = f(X, Y)

# plt.contourf(X, Y, Z, 20, cmap='RdGy')
# plt.colorbar();

# %%
im2 = im
print(im2.shape)
y = range(0,im2.shape[1])
im2[:, np.sin(y)<0,:] = 0
print(im2.max(), im2.min())

plt.imshow(im2)
# plt.savefig('img_with_occlusion_1.png')
# Out:
# (405, 720, 3)
# (255, 0)

# %%
im2 = im
print(im2.shape)
x = range(0, im2.shape[0])
y = range(0,im2.shape[1])
im2[np.sin(x)<0,:,:] = 0
print(im2.max(), im2.min())

plt.imshow(im2)
# Out:
# (405, 720, 3)
# (255, 0)

# %%
im_mask = im.copy()
# print(im3.shape)
x = range(0, im3.shape[0])
y = range(0,im3.shape[1])
# im_mask = np.zeros((im3.shape[0], im3.shape[1]))
for i in x:
    for j in y:
        if np.sin((i+j)/10) < -.7:
            im_mask[i,j,:] = 0
        if np.sin((i-j)/10) < -.7:
            im_mask[i,j,:] = 0
        

ax = plt.imshow(im_mask)
# plt.colorbar()
# plt.ylim(100,120)
# plt.xlim(100,140)

# z[x,y] = np.sin((x+y)/2) < 0
# print(z)
# # w = np.sin(x-y)
# # im3[:,z,:] = 0
# print(im3.max(), im3.min())
# im3[x,y]=z
# plt.imshow(x,y,z)
